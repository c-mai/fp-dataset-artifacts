# %%
import json
import random

def label_to_string(label):
    """Convert numeric label to string."""
    return {0: "entailed", 1: "neutral", 2: "contradiction"}.get(label, "unknown")

def find_mismatches(file_path):
    mismatches = []

    with open(file_path, 'r') as file:
        for line in file:
            data = json.loads(line)

            label = label_to_string(data['label'])
            predicted_label = label_to_string(data['predicted_label'])

            if data['label'] != data['predicted_label']:
                mismatches.append({
                    'label': label,
                    'predicted_label': predicted_label,
                    'premise': data['premise'],
                    'hypothesis': data['hypothesis'],
                    'predicted_scores': data['predicted_scores']
                })

    return mismatches

mismatches = find_mismatches('eval_output/eval_predictions.jsonl')

random.seed(42)
sampled_mismatches = random.sample(mismatches, 25)

for mismatch in sampled_mismatches:
    print(mismatch)
# Out:
# {'label': 'neutral', 'predicted_label': 'contradiction', 'premise': 'A woman walking, smiling and holding a shopping bag.', 'hypothesis': 'Some women go shopping, while men stay at home.', 'predicted_scores': [-4.604426383972168, -0.18738415837287903, 3.454765558242798]}
# {'label': 'neutral', 'predicted_label': 'entailed', 'premise': 'A man is sitting outside wearing blue pants.', 'hypothesis': 'The person is on the ground.', 'predicted_scores': [3.0150976181030273, -0.592652440071106, -2.602357864379883]}
# {'label': 'neutral', 'predicted_label': 'entailed', 'premise': "A baby in an indoor pool is using an inflatable tube on it's on", 'hypothesis': 'The baby is swimming', 'predicted_scores': [0.9003664255142212, 0.49155476689338684, -1.478476643562317]}
# {'label': 'contradiction', 'predicted_label': 'neutral', 'premise': 'The person and the dog are sitting on the yellow canoe.', 'hypothesis': 'The man is using the dog as a paddle.', 'predicted_scores': [-0.9695155024528503, 1.5256019830703735, -0.9775861501693726]}
# {'label': 'entailed', 'predicted_label': 'neutral', 'premise': 'A man with a blue shirt and glasses points to a picture in a book in front of a little girl and a stack of books.', 'hypothesis': 'The man is attempting to draw attention to a picture.', 'predicted_scores': [-0.05151102691888809, 2.0956995487213135, -2.509857416152954]}
# {'label': 'neutral', 'predicted_label': 'entailed', 'premise': 'Several people mill around a sidewalk in front of a building looking as police put up crime scene tape.', 'hypothesis': 'Several people saw a crime committed.', 'predicted_scores': [1.4590497016906738, 0.8907116651535034, -2.615947961807251]}
# {'label': 'contradiction', 'predicted_label': 'neutral', 'premise': 'A woman is tugging on a white sheet and laughing', 'hypothesis': 'The woman is trying on a new dress.', 'predicted_scores': [-3.311537265777588, 3.366077184677124, -0.9422911405563354]}
# {'label': 'contradiction', 'predicted_label': 'neutral', 'premise': 'Six children at a table with a green tablecloth, five female, one male, looking at the camera, plates and condiments at the table, two empty chairs, and red roses in the background', 'hypothesis': 'Half of the children are male.', 'predicted_scores': [-0.27058520913124084, 0.7000024318695068, -0.5509748458862305]}
# {'label': 'contradiction', 'predicted_label': 'entailed', 'premise': 'A clerk at a store is idling a waiting for next customer.', 'hypothesis': 'Clerk is busy ringing up products.', 'predicted_scores': [0.47950369119644165, 0.22365030646324158, -0.6640244722366333]}
# {'label': 'entailed', 'predicted_label': 'contradiction', 'premise': 'Several men in protective suits are rolling a man on a gurnee.', 'hypothesis': 'A man is on a gurney', 'predicted_scores': [-2.2806928157806396, -1.7746822834014893, 3.0285627841949463]}
# {'label': 'neutral', 'predicted_label': 'entailed', 'premise': 'An older woman on the computer', 'hypothesis': 'Woman using her personal computer.', 'predicted_scores': [2.6331303119659424, 0.20418375730514526, -3.062260627746582]}
# {'label': 'entailed', 'predicted_label': 'neutral', 'premise': 'A smiling woman is playing the violin in front of a turquoise background.', 'hypothesis': 'A woman is sitting and playing the violin.', 'predicted_scores': [-0.8907642364501953, 2.474954843521118, -2.177137613296509]}
# {'label': 'neutral', 'predicted_label': 'entailed', 'premise': 'Competitive bikers in an inside race cross a line with one biker in blue and white raising his arm.', 'hypothesis': 'A race between competitive bikers on an inside track begins as a biker raises his arm.', 'predicted_scores': [2.8154585361480713, -0.536622941493988, -2.4557666778564453]}
# {'label': 'contradiction', 'predicted_label': 'neutral', 'premise': 'A lady in a business suit sits at a desk and types on her keyboard.', 'hypothesis': 'the boy liked cowboys', 'predicted_scores': [-3.2650153636932373, 2.9967687129974365, -0.544835090637207]}
# {'label': 'neutral', 'predicted_label': 'entailed', 'premise': "A West Virginia university women's basketball team, officials, and a small gathering of fans are in a West Virginia arena.", 'hypothesis': 'women are playing basketball', 'predicted_scores': [3.1702778339385986, 0.011300534941256046, -3.4348256587982178]}
# {'label': 'contradiction', 'predicted_label': 'neutral', 'premise': 'A man in a green Celtic sleeveless jersey shirt and short stone washed jean shorts sitting and eating.', 'hypothesis': 'The man is wearing a Cowboys jersey.', 'predicted_scores': [-1.4831751585006714, 2.512087106704712, -1.684938669204712]}
# {'label': 'contradiction', 'predicted_label': 'neutral', 'premise': 'Two children in swimming trunks are standing under a water sprinkler while a crowd looks on.', 'hypothesis': 'They play x-box in the sprinkler', 'predicted_scores': [-3.5547542572021484, 1.5866384506225586, 1.13002610206604]}
# {'label': 'neutral', 'predicted_label': 'contradiction', 'premise': 'Young man in a red hat, gray shirt, and jeans, performs a trick in the air with his skateboard.', 'hypothesis': 'The young man has a hunters hat on.', 'predicted_scores': [-3.0411078929901123, -0.8411885499954224, 2.8174917697906494]}
# {'label': 'neutral', 'predicted_label': 'contradiction', 'premise': 'A greyhound jumps over a chain.', 'hypothesis': 'A dog ran away from the racetrack.', 'predicted_scores': [-2.485138416290283, -0.38802990317344666, 2.029283285140991]}
# {'label': 'neutral', 'predicted_label': 'contradiction', 'premise': "A man in his 30's is sitting on a curb of a busy sidewalk, dressed in a furry green costume.", 'hypothesis': 'The man just lost his job playing Oscar the Grouch at Sesame Place because he kicked a child.', 'predicted_scores': [-5.048253536224365, 0.2050783634185791, 3.4610540866851807]}
# {'label': 'neutral', 'predicted_label': 'entailed', 'premise': 'a woman siting in a black polka dot bathing suit top, and blue high waist underwear bottoms sitting in the sidewalk with three bags and a green bottle.', 'hypothesis': 'A woman looks odd sitting on the sidewalk with several bags and a bottle while wearing a bathing suit.', 'predicted_scores': [3.0362274646759033, -0.2841693162918091, -2.9590213298797607]}
# {'label': 'neutral', 'predicted_label': 'contradiction', 'premise': 'A young boy with black hair is holding onto a gun which is secured to a vehicle which is being driven by a young man who is wearing a bright pink shirt.', 'hypothesis': 'The boy is outside and running from cops.', 'predicted_scores': [-4.485769748687744, -0.6517424583435059, 3.747663974761963]}
# {'label': 'entailed', 'predicted_label': 'neutral', 'premise': 'Two construction workers complete a task near the ground while a third worker looks on.', 'hypothesis': 'Workers pull together to get the project completed.', 'predicted_scores': [0.5799882411956787, 0.9099776744842529, -1.670040488243103]}
# {'label': 'neutral', 'predicted_label': 'contradiction', 'premise': 'A man and woman stand facing each other, the man holding an instrument and the woman holding a piece of paper.', 'hypothesis': 'The duo are singing a song.', 'predicted_scores': [-4.215765476226807, -0.3493618071079254, 3.2985117435455322]}
# {'label': 'entailed', 'predicted_label': 'contradiction', 'premise': 'People wait in line at bus stop.', 'hypothesis': 'The bus already has people waiting on it.', 'predicted_scores': [-1.451014518737793, -0.4491880238056183, 1.3324156999588013]}

# %%
import json
from datasets import load_dataset
import nlpaug.augmenter.word as naw

# Load the dataset
dataset = load_dataset('snli', split='validation')

# Initialize the augmenter
aug = naw.SynonymAug(aug_src='wordnet')

def augment_text(text, aug, num_augments=1):
    return [aug.augment(text) for _ in range(num_augments)]

# Open a file to write the examples
with open('augmented_snli.jsonl', 'w') as file:
    for example in dataset.select(range(1000)):  # Assuming we augment the first 100 examples
        # Augment premise and hypothesis
        augmented_premises = augment_text(example['premise'], aug)
        augmented_hypotheses = augment_text(example['hypothesis'], aug)

        # Write the original example
        # original_example = {
        #     'premise': example['premise'],
        #     'hypothesis': example['hypothesis'],
        #     'label': example['label']
        # }
        # file.write(json.dumps(original_example) + '\n')

        # Write each augmented example
        for aug_premise, aug_hypothesis in zip(augmented_premises, augmented_hypotheses):
            augmented_example = {
                'premise': aug_premise[0],
                'hypothesis': aug_hypothesis[0],
                'label': example['label']
            }
            file.write(json.dumps(augmented_example) + '\n')
